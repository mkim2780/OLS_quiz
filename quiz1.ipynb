# %% [markdown]
# # Quiz 1
# ### Min ah Kim

# %%
#import requests library used for HTTP requests
#import BeautifulSoup library pulling data out of HTML and XML files (we can search and modify the data)
import requests
from bs4 import BeautifulSoup


page_to_scrape = requests.get("https://www.ebi.ac.uk/ols4/search?q=parkinson+disease")
soup = BeautifulSoup(page_to_scrape.text, "html.parser")
print(page_to_scrape.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8" />
#     <link rel="icon" href="/ols4favicon.ico" />
#     <link rel="stylesheet" href="/ols4styles.css" />
#     <style>
#       @import url("https://fonts.googleapis.com/css2?family=IBM+Plex+Sans:ital,wght@0,100;0,200;0,300;0,400;0,500;0,600;0,700;1,100;1,200;1,300;1,400;1,500;1,600;1,700&display=swap");
#     </style>
#     <link
#       rel="stylesheet"
#       href="https://ebi.emblstatic.net/web_guidelines/EBI-Icon-fonts/v1.3/fonts.css"
#     />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <meta name="theme-color" content="#000000" />
#     <meta
#       name="description"
#       content="OLS is a repository for biomedical ontologies that aims to provide a single point of access to the latest ontology versions"
#     />
#     <link rel="apple-touch-icon" href="/ols4logo192.png" />
#     <!--
# ...

# %% [markdown]
# Initially, my intention was to extract all HTML elements from the webpage and specifically target those with the class "my-4", as they supposedly contained the search results related to Parkinson's disease.But even though I was able to discover items of the class "my-4" using the findAll() function, I ran into an issue where it was unable to extract any data.
#
# Because of this problem, I decided to take another approach. Rather than depending on automatic extraction techniques, I manually copied and pasted every relevant HTML element associated with Parkinson's illness from the website. In this way, I could be certain that I got the desired search results even in the event that the findAll() function technical difficulties.

# %%
html_content = """<div>
  <div class="flex justify-center p-2 gap-2">
    <button disabled="" class="px-4 py-1 text-neutral-default cursor-not-allowed">Previous</button>
    <button class="px-4 py-1 bg-neutral-default rounded-md text-white cursor-default">1</button>
    <button class="px-4 py-1 text-neutral-default hover:bg-neutral-default hover:rounded-md hover:text-white">2</button>
    <span class="py-1 text-neutral-default">...</span>
    <button class="px-4 py-1 text-neutral-default hover:bg-neutral-default hover:rounded-md hover:text-white">6516</button>
    <button class="px-4 py-1 text-neutral-default hover:bg-neutral-default hover:rounded-md hover:text-white">Next</button>
  </div>
  <div class="my-4">
    <div class="mb-2 leading-loose truncate flex flex-row items-center">
      <a class="link-default text-xl mr-2 font-bold" href="/ols4/ontologies/mondo/classes/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FMONDO_0013625">Parkinson disease 17</a>
      <span class="mr-1">
        <span class="bg-orange-default text-white text-sm rounded-md px-2 py-1 w-fit font-bold break-all">MONDO:0013625</span>&nbsp;&nbsp;
        <i title="Copy ID" class="text-sm text-neutral-default icon icon-common icon-copy icon-spacer cursor-pointer"></i>
      </span>
    </div>
    <div class="mb-1 leading-relaxed text-sm text-neutral-default">http://purl.obolibrary.org/obo/MONDO_0013625</div>
    <div class="mb-1 leading-relaxed">Any Parkinson disease in which the cause of the disease is a mutation in the VPS35 gene.</div>
    <div class="leading-loose">
      <span class="font-bold mr-1">Ontology:</span>&nbsp;
      <a href="/ols4/ontologies/mondo">
        <span class="link-ontology px-2 py-1 rounded-md text-sm text-white uppercase w-fit font-bold break-all" title="MONDO">mondo</span>
      </a>
    </div>
    <div class="leading-loose"></div>
  </div>
  <!-- More similar blocks of information... -->
  <div class="flex justify-center p-2 gap-2">
    <button disabled="" class="px-4 py-1 text-neutral-default cursor-not-allowed">Previous</button>
    <button class="px-4 py-1 bg-neutral-default rounded-md text-white cursor-default">1</button>
    <button class="px-4 py-1 text-neutral-default hover:bg-neutral-default hover:rounded-md hover:text-white"></button>
  </div>
</div>
"""

# Find all div elements with class "my-4"
divs_my_4 = soup.find_all("div", class_="my-4")

# Iterate over each div with class "my-4" and print its content
for div_my_4 in divs_my_4:
    print(div_my_4.text.strip())
    print("-" * 50)
# Out:
# Parkinson disease 13, autosomal dominant, susceptibility toMONDO:0012466  Importedhttp://purl.obolibrary.org/obo/MONDO_0012466Any young-onset Parkinson disease in which the cause of the disease is a mutation in the HTRA2 gene.Ontology: efo
# --------------------------------------------------
# Parkinson disease 5, autosomal dominant, susceptibility toMONDO:0013340  Importedhttp://purl.obolibrary.org/obo/MONDO_0013340An inherited susceptibility or predisposition to developing young-onset Parkinson disease in which the cause of the disease is a mutation in the UCHL1 gene.Ontology: efo
# --------------------------------------------------
# ...

# %%
html_content = '''
<div class="my-4">
 <div class="mb-2 leading-loose truncate flex flex-row items-center"><a class="link-default text-xl mr-2  " href="/ols4/ontologies/efo/classes/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FMONDO_0012466">Parkinson disease 13, autosomal dominant, susceptibility to</a><span class="mr-1"><span class="bg-orange-default text-white text-sm rounded-md px-2 py-1 w-fit font-bold break-all">MONDO:0012466</span>&nbsp;&nbsp;<i title="Copy ID" class="text-sm text-neutral-default icon icon-common icon-copy icon-spacer cursor-pointer"></i></span><span class="text-white text-xs bg-neutral-default px-2 py-1 mr-1 rounded-md uppercase">Imported</span></div><div class="mb-1 leading-relaxed text-sm text-neutral-default">http://purl.obolibrary.org/obo/MONDO_0012466</div><div class="mb-1 leading-relaxed">Any young-onset Parkinson disease in which the cause of the disease is a mutation in the HTRA2 gene.</div><div class="leading-loose"><span class="font-bold mr-1">Ontology:</span>&nbsp;<a href="/ols4/ontologies/efo"><span class="link-ontology px-2 py-1 rounded-md text-sm text-white uppercase w-fit font-bold break-all" title="EFO">efo</span></a></div><div class="leading-loose"></div></div>

<div class="my-4">
 <div class="mb-2 leading-loose truncate flex flex-row items-center"><a class="link-default text-xl mr-2  " href="/ols4/ontologies/efo/classes/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FMONDO_0013340">Parkinson disease 5, autosomal dominant, susceptibility to</a><span class="mr-1"><span class="bg-orange-default text-white text-sm rounded-md px-2 py-1 w-fit font-bold break-all">MONDO:0013340</span>&nbsp;&nbsp;<i title="Copy ID" class="text-sm text-neutral-default icon icon-common icon-copy icon-spacer cursor-pointer"></i></span><span class="text-white text-xs bg-neutral-default px-2 py-1 mr-1 rounded-md uppercase">Imported</span></div><div class="mb-1 leading-relaxed text-sm text-neutral-default">http://purl.obolibrary.org/obo/MONDO_0013340</div><div class="mb-1 leading-relaxed">An inherited susceptibility or predisposition to developing young-onset Parkinson disease in which the cause of the disease is a mutation in the UCHL1 gene.</div><div class="leading-loose"><span class="font-bold mr-1">Ontology:</span>&nbsp;<a href="/ols4/ontologies/efo"><span class="link-ontology px-2 py-1 rounded-md text-sm text-white uppercase w-fit font-bold break-all" title="EFO">efo</span></a></div><div class="leading-loose"></div></div>

<div class="my-4">
 <div class="mb-2 leading-loose truncate flex flex-row items-center"><a class="link-default text-xl mr-2  " href="/ols4/ontologies/efo/classes/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FMONDO_0005180">Parkinson disease</a><span class="mr-1"><span class="bg-orange-default text-white text-sm rounded-md px-2 py-1 w-fit font-bold break-all">MONDO:0005180</span>&nbsp;&nbsp;<i title="Copy ID" class="text-sm text-neutral-default icon icon-common icon-copy icon-spacer cursor-pointer"></i></span><span class="text-white text-xs bg-neutral-default px-2 py-1 mr-1 rounded-md uppercase">Imported</span></div><div class="mb-1 leading-relaxed text-sm text-neutral-default">http://purl.obolibrary.org/obo/MONDO_0005180</div><div class="mb-1 leading-relaxed">A progressive degenerative disorder of the central nervous system characterized by loss of dopamine producing neurons in the substantia nigra and the presence of Lewy bodies in the substantia nigra and locus coeruleus. Signs and symptoms include tremor which is most pronounced during rest, muscle rigidity, slowing of the voluntary movements, a tendency to fall back, and a mask-like facial expression.</div><div class="leading-loose"><span class="font-bold mr-1">Ontology:</span>&nbsp;<a href="/ols4/ontologies/efo"><span class="link-ontology px-2 py-1 rounded-md text-sm text-white uppercase w-fit font-bold break-all" title="EFO">efo</span></a></div><div class="leading-loose"><div class="mb-2" style="max-width: 100%; inline-size: 100%;"><span class="font-bold mr-2">Also appears in:</span><a class="my-2" href="/ols4/ontologies/oba/classes/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FMONDO_0005180" style="display: inline-block;"><span class="link-ontology px-2 py-1 rounded-md text-sm font-bold text-white uppercase mr-1" title="OBA">oba</span></a>&nbsp;</div></div></div>
'''


# Initialize an empty list to store organized results
organized_results = []

# Find all div elements with class "my-4"
divs_my_4 = soup.find_all("div", class_="my-4")

# Iterate over each div with class "my-4" and extract relevant information
for div_my_4 in divs_my_4:
    # Extract disease name
    disease_name = div_my_4.find("a", class_="link-default").text.strip()

    # Extract disease ID
    disease_id = div_my_4.find("span", class_="bg-orange-default").text.strip()

    # Extract description
    description = div_my_4.find("div", class_="mb-1 leading-relaxed").text.strip()

    # Extract ontology
    ontology = div_my_4.find("span", class_="link-ontology").text.strip()

    # Extract "Also appears in" section if it exists
    also_appears_in = div_my_4.find("div", style="max-width: 100%; inline-size: 100%;")
    if also_appears_in:
        also_appears_in_text = also_appears_in.find("span", class_="font-bold mr-2").text.strip()
    else:
        also_appears_in_text = None

    # Construct a dictionary for the current result
    result_dict = {
        "Disease Name": disease_name,
        "Disease ID": disease_id,
        "Description": description,
        "Ontology": ontology,
        "Also appears in": also_appears_in_text
    }

    # Append the dictionary to the organized results list
    organized_results.append(result_dict)

# Print organized results
for result in organized_results:
    print("Disease Name:", result["Disease Name"])
    print("Disease ID:", result["Disease ID"])
    print("Description:", result["Description"])
    print("Ontology:", result["Ontology"])
    print("Also appears in:", result["Also appears in"])
    print("-" * 50)
# Out:
# Disease Name: Parkinson disease 13, autosomal dominant, susceptibility to
# Disease ID: MONDO:0012466
# Description: Any young-onset Parkinson disease in which the cause of the disease is a mutation in the HTRA2 gene.
# Ontology: efo
# Also appears in: None
# --------------------------------------------------
# Disease Name: Parkinson disease 5, autosomal dominant, susceptibility to
# Disease ID: MONDO:0013340
# Description: An inherited susceptibility or predisposition to developing young-onset Parkinson disease in which the cause of the disease is a mutation in the UCHL1 gene.
# Ontology: efo
# Also appears in: None
# --------------------------------------------------
# Disease Name: Parkinson disease
# Disease ID: MONDO:0005180
# ...

# %% [markdown]
# # Analyze
# ### Web Scraping with Python
# Python web scraping makes extract large amounts of data from websites quickly and easily in a straightforward and efficient way. It makes easy update and search functions possible, flexible data manipulation. Web scraping also makes it possible to create graphs and visualizations from the data that is scraped, which opens up new possibilities for analysis and insights.
#
# our goal is to find out the accuracy of a search engine solely for Parkinson's disease. Since there are several disease that are connected to Parkinson's disease, we had to choose the most accurate one. In order for users to find specific information we can use information retrieval techniques, such as cosine similarity, This comparing the similarity between the search term and the retrieval text allowing us to analyze and determine which data even when it isn't immediately apparent from the website structure closely fits the desired search.

# %% [markdown]
# ### Web Searching
# When searching for information on a website, Users can search the website quickly and easily, and you can see the information visually, making it easier to find what you're looking for. for example when I explored the section on Parkinson's disease, so many disease related conditions were appeared and the complete list of relevant diseases was arranged well to make understanding simple.
#
# Additionally, the sorting and filtering features also worked effectively, which helped me with my search. The filtering feature was useful when I needed to find things focused on Parkinson's disease in children within the MONDO area. However sometimes the search results can be inaccurate. For example when i looked at the parkinson disease directed to children it showed only adult disease so i was little bit confused and i wasn't sure if it was correct information.
